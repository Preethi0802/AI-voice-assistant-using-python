# %% [markdown]
# <a href="https://colab.research.google.com/github/Preethi0802/AI-voice-assistant-using-python/blob/main/cleaning_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train =pd.read_csv("/content/train.tsv",sep="\t",error_bad_lines=False)
# Out:
# <ipython-input-8-593eee5fb776>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   train =pd.read_csv("/content/train.tsv",sep="\t",error_bad_lines=False)

# %%
train.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# ...

# %%
train.tail()
# Out:
#        train_id                                      name  item_condition_id  \
# 55570     55570         FS! Snickerdoodle advocare shakes                  1
# 55571     55571  Brand new ♡NEW 20 Piece Makeup Brush Set                  1
# 55572     55572                 Random lot of Naruto toys                  3
# 55573     55573         Zuvi multi color legging bundle S                  3
# 55574     55574             New NYC Polish for Jmanlarkin                  1
#
#                                            category_name brand_name  price  \
# 55570        Other/Daily & Travel items/Sports Nutrition        NaN   24.0
# 55571  Beauty/Tools & Accessories/Makeup Brushes & Tools        NaN    8.0
# 55572                 Kids/Toys/Action Figures & Statues        NaN   13.0
# 55573     Women/Athletic Apparel/Pants, Tights, Leggings        NaN   64.0
# 55574                                Beauty/Makeup/Nails        NaN    9.0
#
# ...

# %%
train.tail()
# Out:
#        train_id                                      name  item_condition_id  \
# 55570     55570         FS! Snickerdoodle advocare shakes                  1
# 55571     55571  Brand new ♡NEW 20 Piece Makeup Brush Set                  1
# 55572     55572                 Random lot of Naruto toys                  3
# 55573     55573         Zuvi multi color legging bundle S                  3
# 55574     55574             New NYC Polish for Jmanlarkin                  1
#
#                                            category_name brand_name  price  \
# 55570        Other/Daily & Travel items/Sports Nutrition        NaN   24.0
# 55571  Beauty/Tools & Accessories/Makeup Brushes & Tools        NaN    8.0
# 55572                 Kids/Toys/Action Figures & Statues        NaN   13.0
# 55573     Women/Athletic Apparel/Pants, Tights, Leggings        NaN   64.0
# 55574                                Beauty/Makeup/Nails        NaN    9.0
#
# ...

# %%
train.head(10)
# Out:
#    train_id                                    name  item_condition_id  \
# 0         0     MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1        Razer BlackWidow Chroma Keyboard                  3
# 2         2                          AVA-VIV Blouse                  1
# 3         3                   Leather Horse Statues                  1
# 4         4                    24K GOLD plated rose                  1
# 5         5        Bundled items requested for Ruie                  3
# 6         6      Acacia pacific tides santorini top                  3
# 7         7    Girls cheer and tumbling bundle of 7                  3
# 8         8                   Girls Nike Pro shorts                  3
# 9         9  Porcelain clown doll checker pants VTG                  3
#
#                                        category_name       brand_name  price  \
# 0                                  Men/Tops/T-shirts              NaN   10.0
# ...

# %%
train.columns
# Out:
# Index(['train_id', 'name', 'item_condition_id', 'category_name', 'brand_name',
#        'price', 'shipping', 'item_description'],
#       dtype='object')

# %%
train.shape
# Out:
# (55575, 8)

# %%
train['price']
# Out:
# 0        10.0
# 1        52.0
# 2        10.0
# 3        35.0
# 4        44.0
#          ...
# 55570    24.0
# 55571     8.0
# 55572    13.0
# 55573    64.0
# 55574     9.0
# Name: price, Length: 55575, dtype: float64

# %%
train['price'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
train['price'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
train['price'].plot.hist(bins=50,figsize=(10,5),range=[0,500],edgecolor="white")
# Out:
# <Axes: ylabel='Frequency'>

# %%
train['price'].max()
# Out:
# 1506.0

# %%
train['price'].min()
# Out:
# 0.0

# %% [markdown]
# train['price'].mean()

# %%
train['price'].mean()
# Out:
# 26.66370670265407

# %%
train['price'].median()
# Out:
# 17.0

# %%
train.quantile([0.25,0.5,0.75])
# Out:
# <ipython-input-23-0a1b9531bd9b>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.quantile([0.25,0.5,0.75])
#       train_id  item_condition_id  price  shipping
# 0.25   13893.5                1.0   10.0       0.0
# 0.50   27787.0                2.0   17.0       0.0
# 0.75   41680.5                3.0   29.0       1.0

# %%
train.describe()
# Out:
#            train_id  item_condition_id         price      shipping
# count  55575.000000       55575.000000  55575.000000  55575.000000
# mean   27787.000000           1.908214     26.663707      0.447395
# std    16043.264942           0.903531     37.834685      0.497230
# min        0.000000           1.000000      0.000000      0.000000
# 25%    13893.500000           1.000000     10.000000      0.000000
# 50%    27787.000000           2.000000     17.000000      0.000000
# 75%    41680.500000           3.000000     29.000000      1.000000
# max    55574.000000           5.000000   1506.000000      1.000000

# %%
train['item_condition_id'].unique()
# Out:
# array([3, 1, 2, 4, 5])

# %%
len(train['item_condition_id'].unique())
# Out:
# 5

# %%
len(train['train_id'].unique())
# Out:
# 55575

# %%
len(train['category_name'].unique())
# Out:
# 898

# %%
(train['category_name'].unique())
# Out:
# array(['Men/Tops/T-shirts',
#        'Electronics/Computers & Tablets/Components & Parts',
#        'Women/Tops & Blouses/Blouse',
#        'Home/Home Décor/Home Décor Accents', 'Women/Jewelry/Necklaces',
#        'Women/Other/Other', 'Women/Swimwear/Two-Piece',
#        'Sports & Outdoors/Apparel/Girls',
#        'Vintage & Collectibles/Collectibles/Doll', 'Beauty/Makeup/Face',
#        'Beauty/Fragrance/Women', 'Women/Dresses/Above Knee, Mini',
#        'Other/Office supplies/School Supplies', 'Women/Shoes/Boots',
#        'Beauty/Makeup/Makeup Sets', 'Beauty/Makeup/Eyes',
#        'Kids/Gear/Backpacks & Carriers', 'Beauty/Makeup/Makeup Palettes',
#        'Women/Tops & Blouses/Tank, Cami',
#        'Women/Athletic Apparel/Sports Bras',
#        'Electronics/Cell Phones & Accessories/Cell Phones & Smartphones',
#        'Electronics/Cell Phones & Accessories/Chargers & Cradles',
#        'Women/Tops & Blouses/T-Shirts', 'Men/Shoes/Athletic',
# ...

# %%
len((train['name'].unique()))
# Out:
# 53098

# %%
((train['name'].unique()))
# Out:
# array(['MLB Cincinnati Reds T Shirt Size XL',
#        'Razer BlackWidow Chroma Keyboard', 'AVA-VIV Blouse', ...,
#        'Random lot of Naruto toys', 'Zuvi multi color legging bundle S',
#        'New NYC Polish for Jmanlarkin'], dtype=object)

# %%
len((train['brand_name'].unique()))
# Out:
# 1599

# %%
((train['brand_name'].unique()))
# Out:
# array([nan, 'Razer', 'Target', ..., 'miss chic', 'Sass & Bide', 'Lanvin'],
#       dtype=object)

# %%
len((train['item_description'].unique()))
# Out:
# 50750

# %%
((train['item_description'].unique()))
# Out:
# array(['No description yet',
#        'This keyboard is in great condition and works like it came out of the box. All of the ports are tested and work perfectly. The lights are customizable via the Razer Synapse app on your PC.',
#        'Adorable top with a hint of lace and a key hole in the back! The pale pink is a 1X, and I also have a 3X available in white!',
#        ...,
#        "Random lot of anime Naruto toys SOLD AS IS- obviously missing parts and stands and it's possible they might have small defeats from being in storage Will wash before shipping out!",
#        '2 pair bundle',
#        'Skin Tight Denim Creme Never Used, Authentic. SUPER CUTE DENIM COLOR No free shipping, I '],
#       dtype=object)

# %%
len((train['shipping'].unique()))
# Out:
# 2

# %%
((train['shipping'].unique()))
# Out:
# array([1, 0])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55575 entries, 0 to 55574
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   train_id           55575 non-null  int64
#  1   name               55575 non-null  object
#  2   item_condition_id  55575 non-null  int64
#  3   category_name      55323 non-null  object
#  4   brand_name         31671 non-null  object
#  5   price              55575 non-null  float64
#  6   shipping           55575 non-null  int64
#  7   item_description   55575 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 3.4+ MB

# %%
miss_value=train.isnull()
miss_value
# Out:
#        train_id   name  item_condition_id  category_name  brand_name  price  \
# 0         False  False              False          False        True  False
# 1         False  False              False          False       False  False
# 2         False  False              False          False       False  False
# 3         False  False              False          False        True  False
# 4         False  False              False          False        True  False
# ...         ...    ...                ...            ...         ...    ...
# 55570     False  False              False          False        True  False
# 55571     False  False              False          False        True  False
# 55572     False  False              False          False        True  False
# 55573     False  False              False          False        True  False
# 55574     False  False              False          False        True  False
#
#        shipping  item_description
# ...

# %%
miss_value_some=train.isnull().sum()
miss_value_some
# Out:
# train_id                 0
# name                     0
# item_condition_id        0
# category_name          252
# brand_name           23904
# price                    0
# shipping                 0
# item_description         0
# dtype: int64

# %%
split_category=train['category_name'].str.split("/")
split_category
# Out:
# 0                                    [Men, Tops, T-shirts]
# 1        [Electronics, Computers & Tablets, Components ...
# 2                          [Women, Tops & Blouses, Blouse]
# 3                   [Home, Home Décor, Home Décor Accents]
# 4                              [Women, Jewelry, Necklaces]
#                                ...
# 55570      [Other, Daily & Travel items, Sports Nutrition]
# 55571    [Beauty, Tools & Accessories, Makeup Brushes &...
# 55572               [Kids, Toys, Action Figures & Statues]
# 55573    [Women, Athletic Apparel, Pants, Tights, Leggi...
# 55574                              [Beauty, Makeup, Nails]
# Name: category_name, Length: 55575, dtype: object

# %%
split_category_mod=train['category_name'].str.split("/",expand=True)
split_category_mod
# Out:
#                  0                     1                         2     3     4
# 0              Men                  Tops                  T-shirts  None  None
# 1      Electronics   Computers & Tablets        Components & Parts  None  None
# 2            Women        Tops & Blouses                    Blouse  None  None
# 3             Home            Home Décor        Home Décor Accents  None  None
# 4            Women               Jewelry                 Necklaces  None  None
# ...            ...                   ...                       ...   ...   ...
# 55570        Other  Daily & Travel items          Sports Nutrition  None  None
# 55571       Beauty   Tools & Accessories    Makeup Brushes & Tools  None  None
# 55572         Kids                  Toys  Action Figures & Statues  None  None
# 55573        Women      Athletic Apparel   Pants, Tights, Leggings  None  None
# 55574       Beauty                Makeup                     Nails  None  None
#
# ...

# %%
split_category_mod.columns=['main_cat','sub_cat1','sub_cat2','sub_cat3','sub_cat4']
split_category_mod
# Out:
#           main_cat              sub_cat1                  sub_cat2 sub_cat3  \
# 0              Men                  Tops                  T-shirts     None
# 1      Electronics   Computers & Tablets        Components & Parts     None
# 2            Women        Tops & Blouses                    Blouse     None
# 3             Home            Home Décor        Home Décor Accents     None
# 4            Women               Jewelry                 Necklaces     None
# ...            ...                   ...                       ...      ...
# 55570        Other  Daily & Travel items          Sports Nutrition     None
# 55571       Beauty   Tools & Accessories    Makeup Brushes & Tools     None
# 55572         Kids                  Toys  Action Figures & Statues     None
# 55573        Women      Athletic Apparel   Pants, Tights, Leggings     None
# 55574       Beauty                Makeup                     Nails     None
#
#       sub_cat4
# 0         None
# 1         None
# ...

# %%
split_category_mod['main_cat'].unique()
# Out:
# array(['Men', 'Electronics', 'Women', 'Home', 'Sports & Outdoors',
#        'Vintage & Collectibles', 'Beauty', 'Other', 'Kids', nan,
#        'Handmade'], dtype=object)

# %%
len(split_category_mod['main_cat'].unique())
# Out:
# 11

# %%
split_category_mod['main_cat'].value_counts()
# Out:
# Women                     24952
# Beauty                     7873
# Kids                       6388
# Electronics                4686
# Men                        3394
# Home                       2466
# Vintage & Collectibles     1784
# Other                      1691
# Handmade                   1163
# Sports & Outdoors           926
# Name: main_cat, dtype: int64

# %%
len(split_category_mod['main_cat'].value_counts())
# Out:
# 10

# %%
split_category_mod['main_cat'].value_counts().plot(kind='bar',color=['green','orange','red','yellow','blue','magenta','purple'])
# Out:
# <Axes: >

# %%
p1700 =train[train['price']>1700]
p1700
# Out:
# Empty DataFrame
# Columns: [train_id, name, item_condition_id, category_name, brand_name, price, shipping, item_description]
# Index: []

# %%
p1700.shape
# Out:
# (0, 8)

# %%
p1850 =train[(train['price']>=1850)&(train['price']<1950)]
p1850
# Out:
# Empty DataFrame
# Columns: [train_id, name, item_condition_id, category_name, brand_name, price, shipping, item_description]
# Index: []

# %%
 p10.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-5e775bbd489e> in <cell line: 1>()
# ----> 1 p10.shape
#
# NameError: name 'p10' is not defined
